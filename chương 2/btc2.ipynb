# %%
# Ex 2:
name = input("Enter your name: ")
print("Hello " + name)

# %%
# Ex 3:
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))
pay = hours * rate
print("Pay: ", pay)
# Out:
# Pay:  276.0

# %%
# Ex 4:
width = 17
height = 12.0

# 1. width//2
print(width//2)
print(type(width//2))
# Out:
# 8
# <class 'int'>

# %%
# Ex 4:
width = 17
height = 12.0

# 2. width/2.0
print(width/2.0)
print(type(width/2.0))
# Out:
# 8.5
# <class 'float'>

# %%
# Ex 4:
width = 17
height = 12.0

# 3. height/3
print(height/3)
print(type(height/3))

# %%
# Ex 4:
width = 17
height = 12.0

# 4. 1 + 2 * 5
print(1 + 2 * 5)
print(type(1 + 2 * 5))

# %%
# Ex 5:
celsius = float(input("Nhiệt độ Celsius:"))
# Công thức từ độ C sang độ F: F = (9/5)*C + 32
fahrenheit = (9/5) * celsius + 32
print("Nhiệt độ Fahrenheit: ", fahrenheit)
# Out:
# Hello hùng anh
